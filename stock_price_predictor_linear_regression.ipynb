# %% [markdown]
# # Linear Regression
#
# ### Baseline benchmark model

# %%
# Import libraries to use
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math, time, csv
from collections import defaultdict
from math import sqrt

from sklearn import linear_model
from sklearn.cross_validation import train_test_split
# Out:
# /Users/yuichihagio/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Load datasets & Analysis
csv_file = './data/TM.csv'
dfTM = pd.read_csv(csv_file, index_col='Date',parse_dates=True)
dfTM.head()
# Out:
#                   Open        High         Low       Close  Adj Close   Volume
# Date
# 2007-07-24  123.779999  123.779999  122.309998  122.489998  98.390572   418000
# 2007-07-25  123.389999  123.410004  121.500000  122.290001  98.229897   557900
# 2007-07-26  122.320000  122.349998  117.050003  119.199997  95.747864  1258500
# 2007-07-27  121.739998  121.739998  119.040001  120.480003  96.776016   679900
# 2007-07-30  122.120003  122.599998  121.000000  121.790001  97.828300   639300

# %%
# Plot 'Date'(X-axis) and 'Adj Close'(Y-axis)
adj_close_TM = dfTM['Adj Close']
adj_close_TM = adj_close_TM.plot(figsize=(12, 9), title="Toyota Motor stock price for past 5 years")
adj_close_TM.set_ylabel("Adjusted Closing Price")

plt.show()

# %% [markdown]
# ## Toyota

# %%
# Load data (Toyota Motor) and split it into training and testing
data = pd.read_csv(csv_file)
dates = pd.DataFrame(np.arange(len(data)))
adj_closes = data['Adj Close']
X_train, X_test, y_train, y_test = train_test_split(dates, adj_closes, test_size = 0.1, random_state = 0)

# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])

regr = linear_model.LinearRegression()
regr.fit(X_train[:int(len(data)*0.9)], y_train[:int(len(data)*0.9)])

TM_MSE = np.mean((regr.predict(X_test) - y_test) ** 2)
TM_RMSE = sqrt(TM_MSE)

print 'Coefficients:', regr.coef_
print 'Variance score', regr.score(X_test, y_test)
print 'Mean Squared Error (MSE)', TM_MSE
print 'Root Mean Squared Error (RMSE)', TM_RMSE

# Plot outputs
fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(X_test, y_test, color='g', s=20, label='Actual Adjusted Close')
plt.plot(X_test, regr.predict(X_test), color='b', linewidth=2, label='Predicted Adjusted Close')

plt.xlabel('Trading days')
plt.ylabel('Adjusted Close Price')

fig_size = plt.rcParams["figure.figsize"]
  
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# Set title
ax.set_title('Actual & Predicted Adjusted Close Price for Toyota Motor')
ax.legend(loc='upper right')

plt.show()
# Out:
# Training set has 2266 samples.
# Testing set has 252 samples.
# Coefficients: [ 0.02359967]
# Variance score 0.584375516676
# Mean Squared Error (MSE) 224.08264758
# Root Mean Squared Error (RMSE) 14.9693903543

# %% [markdown]
# ## Apple

# %%
# Load datasets & Analysis
csv_file = './data/AAPL.csv'
dfAP = pd.read_csv(csv_file, index_col='Date',parse_dates=True)
dfAP.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2007-07-24  19.840000  20.142857  19.164286  19.270000  17.404449  448823200
# 2007-07-25  19.621429  19.765715  19.285715  19.608572  17.710249  374045700
# 2007-07-26  20.844286  21.214285  19.565714  20.857143  18.837940  546657300
# 2007-07-27  20.884285  21.274286  20.540001  20.549999  18.560532  290274600
# 2007-07-30  20.618572  20.778572  19.938572  20.204287  18.248291  276747100

# %%
# Load data (Toyota Motor) and split it into training and testing
data = pd.read_csv(csv_file)
dates = pd.DataFrame(np.arange(len(data)))
adj_closes = data['Adj Close']
X_train, X_test, y_train, y_test = train_test_split(dates, adj_closes, test_size = 0.1, random_state = 0)

# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])

regr = linear_model.LinearRegression()
regr.fit(X_train[:int(len(data)*0.9)], y_train[:int(len(data)*0.9)])

APPL_MSE = np.mean((regr.predict(X_test) - y_test) ** 2)
APPL_RMSE = sqrt(TM_MSE)

print 'Coefficients:', regr.coef_
print 'Variance score', regr.score(X_test, y_test)
print 'Mean Squared Error (MSE)', APPL_MSE
print 'Root Mean Squared Error (RMSE)', APPL_RMSE

# Plot outputs
fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(X_test, y_test, color='g', s=20, label='Actual Adjusted Close')
plt.plot(X_test, regr.predict(X_test), color='b', linewidth=2, label='Predicted Adjusted Close')

plt.xlabel('Trading days')
plt.ylabel('Adjusted Close Price')

fig_size = plt.rcParams["figure.figsize"]
  
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# Set title
ax.set_title('Actual & Predicted Adjusted Close Price for Apple')
ax.legend(loc='upper right')

plt.show()
# Out:
# Training set has 2266 samples.
# Testing set has 252 samples.
# Coefficients: [ 0.05018276]
# Variance score 0.899540147937
# Mean Squared Error (MSE) 139.563948246
# Root Mean Squared Error (RMSE) 14.9693903543

# %% [markdown]
# ## GE

# %%
# Load datasets & Analysis
csv_file = './data/GE.csv'
dfGE = pd.read_csv(csv_file, index_col='Date',parse_dates=True)
dfGE.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-07-24  40.630001  40.980000  40.150002  40.220001  27.954744  46059200
# 2007-07-25  40.570000  40.720001  39.939999  40.419998  28.093742  42112100
# 2007-07-26  40.009998  40.639999  39.349998  39.529999  27.475157  62534800
# 2007-07-27  39.610001  39.740002  38.790001  38.790001  26.960827  48117000
# 2007-07-30  39.029999  39.439999  38.650002  39.270000  27.294455  40083100

# %%
# Load data (Toyota Motor) and split it into training and testing
data = pd.read_csv(csv_file)
dates = pd.DataFrame(np.arange(len(data)))
adj_closes = data['Adj Close']
X_train, X_test, y_train, y_test = train_test_split(dates, adj_closes, test_size = 0.1, random_state = 0)

# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])

regr = linear_model.LinearRegression()
regr.fit(X_train[:int(len(data)*0.9)], y_train[:int(len(data)*0.9)])

GE_MSE = np.mean((regr.predict(X_test) - y_test) ** 2)
GE_RMSE = sqrt(TM_MSE)

print 'Coefficients:', regr.coef_
print 'Variance score', regr.score(X_test, y_test)
print 'Mean Squared Error (MSE)', GE_MSE
print 'Root Mean Squared Error (RMSE)', GE_RMSE

# Plot outputs
fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(X_test, y_test, color='g', s=20, label='Actual Adjusted Close')
plt.plot(X_test, regr.predict(X_test), color='b', linewidth=2, label='Predicted Adjusted Close')

plt.xlabel('Trading days')
plt.ylabel('Adjusted Close Price')

fig_size = plt.rcParams["figure.figsize"]
  
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# Set title
ax.set_title('Actual & Predicted Adjusted Close Price for GE')
ax.legend(loc='upper right')

plt.show()
# Out:
# Training set has 2266 samples.
# Testing set has 252 samples.
# Coefficients: [ 0.00546094]
# Variance score 0.484109315734
# Mean Squared Error (MSE) 21.4913114234
# Root Mean Squared Error (RMSE) 14.9693903543

# %% [markdown]
# ## Microsoft

# %%
# Load datasets & Analysis
csv_file = './data/MSFT.csv'
dfMS = pd.read_csv(csv_file, index_col='Date',parse_dates=True)
dfMS.head()
# Out:
#              Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-07-24  31.01  31.480000  30.709999  30.799999  24.095196  59729300
# 2007-07-25  30.99  31.299999  30.370001  30.709999  24.024784  54950100
# 2007-07-26  30.24  30.530001  29.510000  29.980000  23.453701  87025300
# 2007-07-27  29.93  30.000000  29.360001  29.389999  22.992138  69214600
# 2007-07-30  29.41  29.490000  28.950001  29.400000  22.999956  67499600

# %%
# Load data (Toyota Motor) and split it into training and testing
data = pd.read_csv(csv_file)
dates = pd.DataFrame(np.arange(len(data)))
adj_closes = data['Adj Close']
X_train, X_test, y_train, y_test = train_test_split(dates, adj_closes, test_size = 0.1, random_state = 0)

# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])

regr = linear_model.LinearRegression()
regr.fit(X_train[:int(len(data)*0.9)], y_train[:int(len(data)*0.9)])

MSFT_MSE = np.mean((regr.predict(X_test) - y_test) ** 2)
MSFT_RMSE = sqrt(TM_MSE)

print 'Coefficients:', regr.coef_
print 'Variance score', regr.score(X_test, y_test)
print 'Mean Squared Error (MSE)', MSFT_MSE
print 'Root Mean Squared Error (RMSE)', MSFT_RMSE

# Plot outputs
fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(X_test, y_test, color='g', s=20, label='Actual Adjusted Close')
plt.plot(X_test, regr.predict(X_test), color='b', linewidth=2, label='Predicted Adjusted Close')

plt.xlabel('Trading days')
plt.ylabel('Adjusted Close Price')

fig_size = plt.rcParams["figure.figsize"]
  
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# Set title
ax.set_title('Actual & Predicted Adjusted Close Price for Microsoft')
ax.legend(loc='upper right')

plt.show()
# Out:
# Training set has 2266 samples.
# Testing set has 252 samples.
# Coefficients: [ 0.01708188]
# Variance score 0.801335206508
# Mean Squared Error (MSE) 37.4523711689
# Root Mean Squared Error (RMSE) 14.9693903543

# %% [markdown]
# ## S&P 500

# %%
# Load datasets & Analysis
csv_file = './data/^GSPC.csv'
dfSP = pd.read_csv(csv_file, index_col='Date',parse_dates=True)
dfSP.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-07-24  1541.569946  1541.569946  1508.619995  1511.040039  1511.040039
# 2007-07-25  1511.030029  1524.310059  1503.729980  1518.089966  1518.089966
# 2007-07-26  1518.089966  1518.089966  1465.300049  1482.660034  1482.660034
# 2007-07-27  1482.439941  1488.530029  1458.949951  1458.949951  1458.949951
# 2007-07-30  1458.930054  1477.880005  1454.319946  1473.910034  1473.910034
#
#                 Volume
# Date
# 2007-07-24  4115830000
# 2007-07-25  4283200000
# 2007-07-26  4472550000
# 2007-07-27  4784650000
# 2007-07-30  4128780000

# %%
# Load data (Toyota Motor) and split it into training and testing
data = pd.read_csv(csv_file)
dates = pd.DataFrame(np.arange(len(data)))
adj_closes = data['Adj Close']
X_train, X_test, y_train, y_test = train_test_split(dates, adj_closes, test_size = 0.1, random_state = 0)

# Show the results of the split
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])

regr = linear_model.LinearRegression()
regr.fit(X_train[:int(len(data)*0.9)], y_train[:int(len(data)*0.9)])

GSPC_MSE = np.mean((regr.predict(X_test) - y_test) ** 2)
GSPC_RMSE = sqrt(TM_MSE)

print 'Coefficients:', regr.coef_
print 'Variance score', regr.score(X_test, y_test)
print 'Mean Squared Error (MSE)', GSPC_MSE
print 'Root Mean Squared Error (RMSE)', GSPC_RMSE

# Plot outputs
fig = plt.figure()
ax = fig.add_subplot(111)

plt.scatter(X_test, y_test, color='g', s=20, label='Actual Adjusted Close')
plt.plot(X_test, regr.predict(X_test), color='b', linewidth=2, label='Predicted Adjusted Close')

plt.xlabel('Trading days')
plt.ylabel('Adjusted Close Price')

fig_size = plt.rcParams["figure.figsize"]
  
fig_size[0] = 15
fig_size[1] = 12
plt.rcParams["figure.figsize"] = fig_size

# Set title
ax.set_title('Actual & Predicted Adjusted Close Price for S&P 500')
ax.legend(loc='upper right')

plt.show()
# Out:
# Training set has 2266 samples.
# Testing set has 252 samples.
# Coefficients: [ 0.52792716]
# Variance score 0.807323532712
# Mean Squared Error (MSE) 37539.2002769
# Root Mean Squared Error (RMSE) 14.9693903543

# %% [markdown]
# ## Results

# %%
print 'Toyota (MSE): ', TM_MSE 
print 'Toyota (RMSE): ', TM_RMSE 
print 'Apple (MSE): ', APPL_MSE 
print 'Apple (RMSE): ', APPL_RMSE 
print 'GE (MSE): ', GE_MSE 
print 'GE (RMSE): ', GE_RMSE 
print 'Microsoft (MSE): ', MSFT_MSE 
print 'Microsoft (RMSE): ', MSFT_RMSE 
print 'S&P 500 (MSE): ', GSPC_MSE 
print 'S&P 500 (RMSE): ', GSPC_RMSE
# Out:
# Toyota (MSE):  224.08264758
# Toyota (RMSE):  14.9693903543
# Apple (MSE):  139.563948246
# Apple (RMSE):  14.9693903543
# GE (MSE):  21.4913114234
# GE (RMSE):  14.9693903543
# Microsoft (MSE):  37.4523711689
# Microsoft (RMSE):  14.9693903543
# S&P 500 (MSE):  37539.2002769
# S&P 500 (RMSE):  14.9693903543
